# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect("mi_base.db")
df = pd.read_sql("SELECT * FROM ventas" , conn)
df.head()
# Out:
#    id          producto  precio  stock
# 0   1     Laptop Lenovo    2500     10
# 1   2    Mouse Logitech      45     50
# 2   3  Silla Ergonomica     350     15
# 3   4   Monitor Samsung     800     20
# 4   5        Escritorio     450      8

# %%
conn.close()
