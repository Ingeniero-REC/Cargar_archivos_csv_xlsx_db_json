# %%
import pandas as pd
import openpyxl

# %%
df = pd.read_excel("reporte.xlsx")
df.head()
# Out:
#        mes  ingresos  gastos
# 0    Enero     15000    9000
# 1  Febrero     18500    9800
# 2    Marzo     21000   10200

# %%
df = pd.read_excel("reporte.xlsx", sheet_name="Ventas2023")
df.head()
# Out:
#        mes  ingresos  gastos
# 0    Enero     12000    8000
# 1  Febrero     13500    8300
# 2    Marzo     14800    8600

# %%
df_todas = pd.read_excel("reporte.xlsx", sheet_name=None)
print(df_todas.keys())
# Out:
# dict_keys(['Ventas2024', 'Ventas2023'])

# %%
df_todas["Ventas2024"]
# Out:
#        mes  ingresos  gastos
# 0    Enero     15000    9000
# 1  Febrero     18500    9800
# 2    Marzo     21000   10200
